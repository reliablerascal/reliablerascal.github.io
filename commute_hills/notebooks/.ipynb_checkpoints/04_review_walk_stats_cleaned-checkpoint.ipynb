# %% [markdown]
# <h1>Import Libraries</h1>

# %%
# import altair with an abbreviated alias
import altair as alt
import csv
import pandas as pd

# %% [markdown]
# <h1>Review Riverside</h1>

# %%
df_walk_riverside = pd.read_csv("../results/commute_riverside_cleaned_stats.csv", index_col=[0])
df_walk_riverside
# Out:
#           lat      long   elev  d_distance  d_height     slope  slope_angle  \
# 0    40.83471 -73.94743  26.10    0.000000      0.00  0.000000     0.000000
# 1    40.83472 -73.94747  26.01    3.541924     -0.09 -0.025410    -1.455568
# 2    40.83444 -73.94766  26.27   34.976220      0.26  0.007434     0.425907
# 3    40.83432 -73.94775  26.00   15.332378     -0.27 -0.017610    -1.008863
# 4    40.83413 -73.94808  23.63   34.865646     -2.37 -0.067975    -3.888711
# ..        ...       ...    ...         ...       ...       ...          ...
# 132  40.80850 -73.96473  36.96    7.509398      2.94  0.391509    21.380811
# 133  40.80820 -73.96403  41.00   67.660476      4.04  0.059710     3.417068
# 134  40.80818 -73.96404  41.00    2.376337      0.00  0.000000     0.000000
# 135  40.80812 -73.96409  40.58    7.883034     -0.42 -0.053279    -3.049777
# 136  40.80811 -73.96409  40.49    1.111251     -0.09 -0.080990    -4.630267
#
#      d_calories  calories_sum  distance_sum
# ...

# %%
alt.Chart(df_walk_riverside).mark_circle(size=30).encode(
    x='distance_sum',
    y='elev',
    #color='segment',
    tooltip=['lat', 'long', 'slope_angle']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# <h3>segmenting</h3>
# try to segment at 139th & 125th to match Broadway data

# %%
#find section endpoints
#no wizardry here, just picked segments based on scatterplot...
#...at around 1,500m and 2,500m to match Broadway segmentation
end_segment1 = df_walk_riverside.loc[df_walk_riverside['lat'] == 40.82344].index[0]
end_segment2 = df_walk_riverside.loc[df_walk_riverside['lat'] == 40.81669].index[0]
end_segment3 = len(df_walk_riverside)
df_walk_riverside["seg_id"]=0
df_walk_riverside["segment"]=0

# %%
#assign segments
df_walk_riverside["seg_id"].loc[0:end_segment1] = 1
df_walk_riverside["seg_id"].loc[end_segment1:end_segment2] = 2
df_walk_riverside["seg_id"].loc[end_segment2:end_segment3] = 3
df_walk_riverside["segment"].loc[0:end_segment1] = '157_139'
df_walk_riverside["segment"].loc[end_segment1:end_segment2] = '139_125'
df_walk_riverside["segment"].loc[end_segment2:end_segment3] = '125_116'
df_walk_riverside
# Out:
# /tmp/ipykernel_1404/4053637319.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_walk_riverside["seg_id"].loc[0:end_segment1] = 1
# /tmp/ipykernel_1404/4053637319.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_walk_riverside["seg_id"].loc[end_segment1:end_segment2] = 2
# /tmp/ipykernel_1404/4053637319.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
alt.Chart(df_walk_riverside).mark_circle(size=30).encode(
    x='distance_sum',
    y='elev',
    color='segment:N',
    #sort = 'seg_id',
    #color = alt.color('segment:N').sort('seg_id'),
    tooltip=['lat', 'long', 'slope_angle']
).interactive()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1404/1664799764.py in <module>
#       6     #color = alt.color('segment:N').sort('seg_id'),
#       7     tooltip=['lat', 'long', 'slope_angle']
# ----> 8 ).interactive().sort('seg_id')
#
# ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py in __getattr__(self, attr)
#     703             except AttributeError:
#     704                 _getattr = super(SchemaBase, self).__getattribute__
# --> 705             return _getattr(attr)
#     706
#     707     def __setattr__(self, item, val):
#
# AttributeError: 'Chart' object has no attribute 'sort'

# %%
df_walk_riverside.to_csv("../results/commute_riverside_segmented.csv")
