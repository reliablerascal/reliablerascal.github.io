# %% [markdown]
# <h1>Shaping Walking Data</h1>
# This notebook takes .gpx data (e.g. exported from Strava or AllTrails), creates two dataframes for further analysis, and exports these dataframes as .csv
# <ol>
# <li>Full dataset, in this example commute_riverside_full.csv, containing all interesting data and calculated fields
# <li>Two-column dataset for plotting in D3
# </ol>

# %% [markdown]
# <h1>Set Parameters</h1>

# %%
path_input = '../data/commute_riverside_alltrails.gpx'
path_output = '../data/commute_riverside.csv'

# %% [markdown]
# <h1>Import Needed Libraries</h1>

# %%
import csv
import pandas as pd

#for reading GPX files

import gpxpy 

#for calculating distance and slope
import geopy.distance 
import numpy as np

#for calculating degrees
#import math

# %% [markdown]
# <h1>Read and Parse GPX File</h1>

# %%
# Open the GPX file (created by AllTrails) and create a GPX object
with open(path_input, 'r') as f:
    gpx = gpxpy.parse(f)

# %%
#inspect and identify fields I needed
gpx.tracks[0].segments[0].points
# Out:
# [GPXTrackPoint(40.83471, -73.94743, elevation=26.1),
#  GPXTrackPoint(40.83472, -73.94747, elevation=26.01),
#  GPXTrackPoint(40.83444, -73.94766, elevation=26.27),
#  GPXTrackPoint(40.83432, -73.94775, elevation=26.0),
#  GPXTrackPoint(40.83413, -73.94808, elevation=23.63),
#  GPXTrackPoint(40.83409, -73.94837, elevation=19.67),
#  GPXTrackPoint(40.83416, -73.94861, elevation=17.02),
#  GPXTrackPoint(40.83423, -73.94882, elevation=16.43),
#  GPXTrackPoint(40.8343, -73.94898, elevation=16.45),
#  GPXTrackPoint(40.83435, -73.94909, elevation=17.15),
#  GPXTrackPoint(40.83428, -73.94914, elevation=16.38),
#  GPXTrackPoint(40.83404, -73.94931, elevation=11.18),
#  GPXTrackPoint(40.83404, -73.94931, elevation=11.18),
#  GPXTrackPoint(40.83404, -73.9493, elevation=11.25),
#  GPXTrackPoint(40.83398, -73.94934, elevation=8.98),
#  GPXTrackPoint(40.8327, -73.94971, elevation=16.84),
#  GPXTrackPoint(40.83259, -73.94968, elevation=19.06),
#  GPXTrackPoint(40.83252, -73.94966, elevation=20.57),
#  GPXTrackPoint(40.83229, -73.94961, elevation=22.42),
#  GPXTrackPoint(40.83215, -73.94959, elevation=23.0),
#  GPXTrackPoint(40.83208, -73.94958, elevation=23.0),
#  GPXTrackPoint(40.83186, -73.94956, elevation=23.75),
#  GPXTrackPoint(40.83162, -73.94956, elevation=23.75),
#  GPXTrackPoint(40.83149, -73.94957, elevation=23.64),
#  GPXTrackPoint(40.83146, -73.94958, elevation=23.54),
#  GPXTrackPoint(40.83141, -73.94958, elevation=23.54),
#  GPXTrackPoint(40.83119, -73.94963, elevation=24.0),
#  GPXTrackPoint(40.83086, -73.94976, elevation=23.88),
#  GPXTrackPoint(40.83078, -73.94979, elevation=24.15),
#  GPXTrackPoint(40.83057, -73.94988, elevation=23.89),
#  GPXTrackPoint(40.83044, -73.94992, elevation=23.86),
#  GPXTrackPoint(40.83031, -73.94995, elevation=23.84),
#  GPXTrackPoint(40.8301, -73.94998, elevation=23.28),
#  GPXTrackPoint(40.82993, -73.95001, elevation=23.0),
#  GPXTrackPoint(40.82984, -73.95002, elevation=23.0),
#  GPXTrackPoint(40.82965, -73.95007, elevation=23.24),
#  GPXTrackPoint(40.82962, -73.95007, elevation=23.32),
#  GPXTrackPoint(40.82961, -73.95008, elevation=23.32),
#  GPXTrackPoint(40.82953, -73.95011, elevation=24.08),
#  GPXTrackPoint(40.82893, -73.95039, elevation=25.91),
#  GPXTrackPoint(40.8283, -73.95086, elevation=25.82),
#  GPXTrackPoint(40.82768, -73.95132, elevation=25.76),
#  GPXTrackPoint(40.82714, -73.95192, elevation=25.23),
#  GPXTrackPoint(40.82708, -73.95198, elevation=25.33),
#  GPXTrackPoint(40.82708, -73.95198, elevation=25.33),
#  GPXTrackPoint(40.82708, -73.95198, elevation=25.33),
#  GPXTrackPoint(40.82642, -73.95253, elevation=23.68),
#  GPXTrackPoint(40.82582, -73.95301, elevation=22.0),
#  GPXTrackPoint(40.82576, -73.95303, elevation=22.0),
#  GPXTrackPoint(40.82558, -73.95324, elevation=21.0),
#  GPXTrackPoint(40.82544, -73.95345, elevation=19.94),
#  GPXTrackPoint(40.82534, -73.95367, elevation=19.0),
#  GPXTrackPoint(40.82531, -73.95373, elevation=19.0),
#  GPXTrackPoint(40.82527, -73.95377, elevation=19.0),
#  GPXTrackPoint(40.82474, -73.95435, elevation=20.81),
#  GPXTrackPoint(40.82413, -73.95483, elevation=19.84),
#  GPXTrackPoint(40.82373, -73.95519, elevation=17.68),
#  GPXTrackPoint(40.82365, -73.95529, elevation=17.5),
#  GPXTrackPoint(40.82359, -73.95532, elevation=17.65),
#  GPXTrackPoint(40.82354, -73.95534, elevation=17.84),
#  GPXTrackPoint(40.82347, -73.95537, elevation=18.0),
#  GPXTrackPoint(40.82344, -73.95539, elevation=17.97),
#  GPXTrackPoint(40.82294, -73.95566, elevation=18.9),
#  GPXTrackPoint(40.8228, -73.95572, elevation=19.0),
#  GPXTrackPoint(40.82274, -73.95575, elevation=19.37),
#  GPXTrackPoint(40.8225, -73.95589, elevation=20.0),
#  GPXTrackPoint(40.82229, -73.95607, elevation=21.67),
#  GPXTrackPoint(40.82224, -73.95611, elevation=22.0),
#  GPXTrackPoint(40.82169, -73.95675, elevation=23.77),
#  GPXTrackPoint(40.8213, -73.95722, elevation=22.98),
#  GPXTrackPoint(40.8212, -73.95736, elevation=23.53),
#  GPXTrackPoint(40.82116, -73.95749, elevation=22.58),
#  GPXTrackPoint(40.82112, -73.95759, elevation=22.9),
#  GPXTrackPoint(40.82109, -73.95774, elevation=21.64),
#  GPXTrackPoint(40.82105, -73.95786, elevation=20.19),
#  GPXTrackPoint(40.82105, -73.95786, elevation=20.19),
#  GPXTrackPoint(40.82105, -73.95786, elevation=20.19),
#  GPXTrackPoint(40.82104, -73.95789, elevation=19.36),
#  GPXTrackPoint(40.82101, -73.95794, elevation=17.65),
#  GPXTrackPoint(40.82097, -73.95804, elevation=15.25),
#  GPXTrackPoint(40.82093, -73.95811, elevation=14.41),
#  GPXTrackPoint(40.82091, -73.95816, elevation=14.0),
#  GPXTrackPoint(40.82087, -73.95822, elevation=14.0),
#  GPXTrackPoint(40.82081, -73.95828, elevation=13.43),
#  GPXTrackPoint(40.82063, -73.95842, elevation=13.0),
#  GPXTrackPoint(40.81753, -73.9607, elevation=2.0),
#  GPXTrackPoint(40.81753, -73.9607, elevation=2.0),
#  GPXTrackPoint(40.81753, -73.9607, elevation=2.0),
#  GPXTrackPoint(40.81696, -73.96112, elevation=14.59),
#  GPXTrackPoint(40.81689, -73.96117, elevation=18.15),
#  GPXTrackPoint(40.81686, -73.96122, elevation=21.07),
#  GPXTrackPoint(40.81683, -73.96125, elevation=24.03),
#  GPXTrackPoint(40.8168, -73.96128, elevation=26.57),
#  GPXTrackPoint(40.81676, -73.96131, elevation=28.96),
#  GPXTrackPoint(40.81672, -73.96136, elevation=29.0),
#  GPXTrackPoint(40.81669, -73.96138, elevation=29.0),
#  GPXTrackPoint(40.81664, -73.96143, elevation=28.68),
#  GPXTrackPoint(40.81658, -73.9615, elevation=28.75),
#  GPXTrackPoint(40.81653, -73.96156, elevation=28.56),
#  GPXTrackPoint(40.81649, -73.96162, elevation=28.91),
#  GPXTrackPoint(40.81634, -73.96189, elevation=28.53),
#  GPXTrackPoint(40.81624, -73.962, elevation=28.76),
#  GPXTrackPoint(40.8162, -73.96205, elevation=28.87),
#  GPXTrackPoint(40.81615, -73.9621, elevation=28.71),
#  GPXTrackPoint(40.81611, -73.96215, elevation=29.0),
#  GPXTrackPoint(40.81609, -73.96217, elevation=29.0),
#  GPXTrackPoint(40.81603, -73.96223, elevation=28.99),
#  GPXTrackPoint(40.81599, -73.96226, elevation=29.18),
#  GPXTrackPoint(40.81596, -73.9623, elevation=29.1),
#  GPXTrackPoint(40.81591, -73.96234, elevation=28.77),
#  GPXTrackPoint(40.81585, -73.96238, elevation=28.87),
#  GPXTrackPoint(40.81579, -73.96243, elevation=28.87),
#  GPXTrackPoint(40.81571, -73.96248, elevation=29.07),
#  GPXTrackPoint(40.81488, -73.96288, elevation=32.27),
#  GPXTrackPoint(40.81396, -73.96337, elevation=34.23),
#  GPXTrackPoint(40.81336, -73.9637, elevation=35.04),
#  GPXTrackPoint(40.81324, -73.96376, elevation=35.39),
#  GPXTrackPoint(40.81314, -73.9638, elevation=35.08),
#  GPXTrackPoint(40.81308, -73.96382, elevation=35.55),
#  GPXTrackPoint(40.81298, -73.96385, elevation=35.42),
#  GPXTrackPoint(40.81289, -73.96387, elevation=35.83),
#  GPXTrackPoint(40.81284, -73.96388, elevation=36.0),
#  GPXTrackPoint(40.81281, -73.96388, elevation=36.0),
#  GPXTrackPoint(40.81274, -73.96389, elevation=36.42),
#  GPXTrackPoint(40.81271, -73.96389, elevation=36.74),
#  GPXTrackPoint(40.8124, -73.9639, elevation=38.0),
#  GPXTrackPoint(40.81229, -73.9639, elevation=38.0),
#  GPXTrackPoint(40.81204, -73.9639, elevation=38.0),
#  GPXTrackPoint(40.81188, -73.96389, elevation=37.0),
#  GPXTrackPoint(40.81175, -73.9639, elevation=37.0),
#  GPXTrackPoint(40.81163, -73.96393, elevation=36.6),
#  GPXTrackPoint(40.81157, -73.96395, elevation=36.0),
#  GPXTrackPoint(40.81152, -73.96397, elevation=36.0),
#  GPXTrackPoint(40.81147, -73.96399, elevation=36.0),
#  GPXTrackPoint(40.81138, -73.96404, elevation=35.9),
#  GPXTrackPoint(40.81129, -73.9641, elevation=35.0),
#  GPXTrackPoint(40.81084, -73.96443, elevation=34.0),
#  GPXTrackPoint(40.81079, -73.96447, elevation=34.0),
#  GPXTrackPoint(40.81074, -73.9645, elevation=34.0),
#  GPXTrackPoint(40.81, -73.96503, elevation=33.0),
#  GPXTrackPoint(40.80895, -73.96581, elevation=29.0),
#  GPXTrackPoint(40.80886, -73.96589, elevation=29.0),
#  GPXTrackPoint(40.80886, -73.96589, elevation=29.0),
#  GPXTrackPoint(40.80886, -73.96589, elevation=29.0),
#  GPXTrackPoint(40.80882, -73.96579, elevation=29.35),
#  GPXTrackPoint(40.80878, -73.9657, elevation=30.0),
#  GPXTrackPoint(40.80866, -73.96541, elevation=31.0),
#  GPXTrackPoint(40.80848, -73.96498, elevation=33.09),
#  GPXTrackPoint(40.80857, -73.96491, elevation=32.98),
#  GPXTrackPoint(40.80853, -73.96481, elevation=34.02),
#  GPXTrackPoint(40.8085, -73.96473, elevation=36.96),
#  GPXTrackPoint(40.8082, -73.96403, elevation=41.0),
#  GPXTrackPoint(40.80818, -73.96404, elevation=41.0),
#  GPXTrackPoint(40.80812, -73.96409, elevation=40.58),
#  GPXTrackPoint(40.80811, -73.96409, elevation=40.49)]

# %%
#grab what I need from the GPX file
df_walk = pd.DataFrame([
{
    "lat": track_point.latitude,
    "long": track_point.longitude,
    "elev": track_point.elevation, #meters
} for track_point in gpx.tracks[0].segments[0].points])

df_walk.head()
# Out:
#         lat      long   elev
# 0  40.83471 -73.94743  26.10
# 1  40.83472 -73.94747  26.01
# 2  40.83444 -73.94766  26.27
# 3  40.83432 -73.94775  26.00
# 4  40.83413 -73.94808  23.63

# %% [markdown]
# <h1>Export It</h1>

# %%
df_walk.to_csv(path_output)
